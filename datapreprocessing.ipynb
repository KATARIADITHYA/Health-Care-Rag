# %%
import pandas as pd
import numpy as np
df = pd.read_csv('cdc_health_topics.csv')
print(df)
# Out:
#                                            disease_name  \
# 0                                 Abortion Surveillance
# 1     Abuse, Child — see Child Abuse and Neglect Pre...
# 2                        Abuse, Elder — see Elder Abuse
# 3                                   Abusive Head Trauma
# 4                                 AcanthamoebaInfection
# ...                                                 ...
# 1709                                  — see Alcohol Use
# 1710         — see NNDSS Modernization Initiative (NMI)
# 1711                                        3D Printing
# 1712        Pseudomonas folliculitis — see Hot Tub Rash
# 1713                                            \ (IBD)
#
#                                                     url
# 0     https://www.cdc.gov/reproductive-health/data-s...
# 1     https://www.cdc.gov/child-abuse-neglect/about/...
# 2      https://www.cdc.gov/elder-abuse/about/index.html
# 3     https://www.cdc.gov/child-abuse-neglect/about/...
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                            disease_name  \
# 0                                 Abortion Surveillance
# 1     Abuse, Child — see Child Abuse and Neglect Pre...
# 2                        Abuse, Elder — see Elder Abuse
# 3                                   Abusive Head Trauma
# 4                                 AcanthamoebaInfection
# ...                                                 ...
# 1709                                  — see Alcohol Use
# 1710         — see NNDSS Modernization Initiative (NMI)
# 1711                                        3D Printing
# 1712        Pseudomonas folliculitis — see Hot Tub Rash
# 1713                                            \ (IBD)
#
#                                                     url
# 0     https://www.cdc.gov/reproductive-health/data-s...
# 1     https://www.cdc.gov/child-abuse-neglect/about/...
# 2      https://www.cdc.gov/elder-abuse/about/index.html
# 3     https://www.cdc.gov/child-abuse-neglect/about/...
# ...

# %%
df=df.sort_values(by="disease_name")

# %%
df[:10]
# Out:
#                                            disease_name  \
# 1711                                        3D Printing
# 7                                  ACIP Recommendations
# 16                                                 ADHD
# 27                           AFIX Immunization Strategy
# 78                              ARRA — see Recovery Act
# 0                                 Abortion Surveillance
# 1     Abuse, Child — see Child Abuse and Neglect Pre...
# 2                        Abuse, Elder — see Elder Abuse
# 3                                   Abusive Head Trauma
# 4                                 AcanthamoebaInfection
#
#                                                     url
# 1711  https://www.cdc.gov/niosh/manufacturing/additi...
# 7               https://www.cdc.gov/acip-recs/site.html
# 16                            https://www.cdc.gov/adhd/
# 27    https://www.cdc.gov/iqip/hcp/at-a-glance/index...
# 78                         https://www.cdc.gov/funding/
# ...

# %%
df.to_csv('cdc_health_topics_cleaned.csv', index=False)
